# %% [markdown]
# SpaCy convierte una lista de caracteres en texto en un objeto Doc, para que la computadora lo pueda interpretar.

# %% [markdown]
# ## Parte 1: El Problema - El Texto es solo una "Sopa de Letras" para la Computadora

# %%
texto = "La CEO de ACME, Lisa Chang, viajará a México para supervisar los nuevos proyectos de energía renovable. Ella se mostró muy entusiasmada."
print(texto)
# Out:
# La CEO de ACME, Lisa Chang, viajará a México para supervisar los nuevos proyectos de energía renovable. Ella se mostró muy entusiasmada.

# %% [markdown]
# ¿Cómo contamos las palabras acá?
# len(texto) nos da los caracteres, no sirve. Podríamos usar texto.split(). Hagamos la prueba.

# %%
palabras = texto.split()
print(palabras)
# Out:
# ['La', 'CEO', 'de', 'ACME,', 'Lisa', 'Chang,', 'viajará', 'a', 'México', 'para', 'supervisar', 'los', 'nuevos', 'proyectos', 'de', 'energía', 'renovable.', 'Ella', 'se', 'mostró', 'muy', 'entusiasmada.']

# %% [markdown]
#  Limitaciones (El "Porqué" necesitamos algo mejor):
#
# - "ACME," y "Chang," tienen la coma pegada. No son palabras "limpias".
# - "La" y "los" son artículos. viajará es una forma conjugada del verbo "viajar". ¿Cómo reducimos todo a su forma base para poder analizar frecuencias o temas?
# - ¿Cómo sabe la máquina que "ACME" es una organización y "Lisa Chang" es una persona? Para Python, ahora mismo, son solo cadenas de texto idénticas a "proyectos".

# %% [markdown]
# ## Parte 2: La Solución - spaCy, el Intérprete Lingüístico

# %%
# !pip install spacy -q
# !python -m spacy download es_core_news_lg -q #para bajar la biblioteca large

# %%
# !pip install spacy -q
# !python -m spacy download es_core_news_sm -q #para bajar la libreria small
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 100.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# Cargar el modelo de español
nlp = spacy.load("es_core_news_sm")

# Procesar nuestro texto
doc = nlp(texto)

print(doc)
# Out:
# La CEO de ACME, Lisa Chang, viajará a México para supervisar los nuevos proyectos de energía renovable. Ella se mostró muy entusiasmada.

# %% [markdown]
# ## Parte 3: Desglosando el Objeto Doc - Los Fundamentos de NLP en Acción

# %% [markdown]
# **Tokenización (La Unidad Mínima)**
#
# Definición: Un token es la unidad mínima de texto con significado (una palabra, un número, un signo de puntuación).

# %%
for token in doc:
    print(token.text)
# Out:
# La
# CEO
# de
# ACME
# ,
# Lisa
# Chang
# ,
# viajará
# a
# México
# para
# supervisar
# los
# nuevos
# proyectos
# de
# energía
# renovable
# .
# Ella
# se
# mostró
# muy
# entusiasmada
# .

# %% [markdown]
# **Lematización (La Raíz de la Palabra)**
#
# Definición: El "lema" es la forma canónica o de diccionario de una palabra. Es la clave para agrupar palabras con el mismo significado.

# %%
print("PALABRA\t\tLEMA")
print("-------\t\t----")
for token in doc:
    # Imprimimos el texto del token y su lema
    print(f"{token.text:<15}\t{token.lemma_}") #encuentra la raiz de la palabra
# Out:
# PALABRA		LEMA
# -------		----
# La             	el
# CEO            	CEO
# de             	de
# ACME           	ACME
# ,              	,
# Lisa           	Lisa
# Chang          	Chang
# ,              	,
# viajará        	viajar
# a              	a
# México         	México
# para           	para
# supervisar     	supervisar
# los            	el
# nuevos         	nuevo
# proyectos      	proyecto
# de             	de
# energía        	energía
# renovable      	renovable
# .              	.
# Ella           	él
# se             	él
# mostró         	mostrar
# muy            	mucho
# entusiasmada   	entusiasmado
# .              	.

# %% [markdown]
# **Part-of-Speech (POS) Tagging (El Rol Gramatical)**
#
# Definición: Etiquetar cada palabra según su función gramatical (Sustantivo, Verbo, Adjetivo, etc.).

# %%
print("PALABRA\t\tPOS\t\tEXPLICACIÓN")
print("-------\t\t---\t\t-----------")
for token in doc:
    print(f"{token.text:<15}\t{token.pos_:<10}\t{spacy.explain(token.pos_)}")
# Out:
# PALABRA		POS		EXPLICACIÓN
# -------		---		-----------
# La             	DET       	determiner
# CEO            	PROPN     	proper noun
# de             	ADP       	adposition
# ACME           	PROPN     	proper noun
# ,              	PUNCT     	punctuation
# Lisa           	PROPN     	proper noun
# Chang          	PROPN     	proper noun
# ,              	PUNCT     	punctuation
# viajará        	VERB      	verb
# a              	ADP       	adposition
# México         	PROPN     	proper noun
# para           	ADP       	adposition
# supervisar     	VERB      	verb
# los            	DET       	determiner
# nuevos         	ADJ       	adjective
# proyectos      	NOUN      	noun
# de             	ADP       	adposition
# energía        	NOUN      	noun
# renovable      	ADJ       	adjective
# .              	PUNCT     	punctuation
# Ella           	PRON      	pronoun
# se             	PRON      	pronoun
# mostró         	VERB      	verb
# muy            	ADV       	adverb
# entusiasmada   	ADJ       	adjective
# .              	PUNCT     	punctuation

# %% [markdown]
# print("PALABRA\t\tPOS\t\tEXPLICACIÓN")
#
# print("-------\t\t---\t\t-----------")
#
# Imprime un encabezado de tabla con tres columnas:
#
# PALABRA → el token (la palabra).
#
# POS → la etiqueta gramatical asignada por spaCy.
#
# EXPLICACIÓN → una breve descripción en lenguaje natural de la etiqueta POS.
#
# ---

# %% [markdown]
# for token in doc:
#
# 👉 Itera sobre cada token del objeto doc.
# Un doc en spaCy es el resultado de procesar un texto con el modelo de lenguaje (nlp(texto)), y contiene todas las palabras/tokenizaciones.

# %% [markdown]
# print(f"{token.text:<15}\t{token.pos_:<10}\t{spacy.explain(token.pos_)}")
#
# 👉 Para cada token imprime en una fila:
#
# token.text → la palabra tal cual aparece en el texto.
# :<15 → significa que se reserva un espacio de 15 caracteres alineado a la izquierda (para que quede en formato tabular).
#
# token.pos_ → la etiqueta gramatical en formato string (ej: NOUN, VERB, ADJ).
# :<10 → reserva 10 caracteres.
#
# spacy.explain(token.pos_) → devuelve una breve explicación de qué significa esa etiqueta POS (ejemplo: "noun" → sustantivo, "verb" → verbo).
