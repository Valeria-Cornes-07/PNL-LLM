# %%
# !pip install watermark -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.3 MB/s eta 0:00:00

# %%
# %load_ext watermark
# %watermark
# %watermark --iversions
# Out:
# Last updated: 2025-08-26T22:45:18.772445+00:00
#
# Python implementation: CPython
# Python version       : 3.12.11
# IPython version      : 7.34.0
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.1.123+
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 2
# Architecture: 64bit

# %%
# !pip install spacy -q

# %%
# !python -m spacy download es_core_news_lg -q #para textos largos. podemos repetir los ejemplos adaptando la longitud de los textos

# %%
# !python -m spacy download es_core_news_sm -q #para textos breves, instalamos ésta
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 98.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# %%
nlp = spacy.load("es_core_news_lg") #para textos largos
import es_core_news_lg
nlp = es_core_news_lg.load()

# %%
nlp = spacy.load("es_core_news_sm") #para textos cortos, cargamos esta
import es_core_news_sm
nlp = es_core_news_sm.load()

# %% [markdown]
# ## Caso 1

# %%
doc = nlp(u'Yo, Matías Barreto, estoy volando hacia Buenos Aires.')
print([w.text for w in doc])
# Out:
# ['Yo', ',', 'Matías', 'Barreto', ',', 'estoy', 'volando', 'hacia', 'Buenos', 'Aires', '.']

# %%
# Length of sentence
print("La cantidad de tokens es: ", len(doc))
# Out:
# La cantidad de tokens es:  11

# %%
# Print individual words (i.e., tokens)
print("Los tokens son: \n" + "_" * 20 + "\n")
for words in doc:
    print(words)
# Out:
# Los tokens son:
# ____________________
#
# Yo
# ,
# Matías
# Barreto
# ,
# estoy
# volando
# hacia
# Buenos
# Aires
# .

# %%
for token in doc:
  print(token.text, token.lemma_)
# Out:
# Yo yo
# , ,
# Matías Matías
# Barreto Barreto
# , ,
# estoy estar
# volando volar
# hacia hacia
# Buenos Buenos
# Aires Aires
# . .

# %%
# Iterar sobre los tokens en el documento y mostrar el texto y su etiqueta POS
for token in doc:
    print(token.text, token.pos_, spacy.explain(token.pos_))
# Out:
# Yo PRON pronoun
# , PUNCT punctuation
# Matías PROPN proper noun
# Barreto PROPN proper noun
# , PUNCT punctuation
# estoy AUX auxiliary
# volando VERB verb
# hacia ADP adposition
# Buenos PROPN proper noun
# Aires PROPN proper noun
# . PUNCT punctuation

# %%
from collections import Counter

# %%
word_freq = Counter(doc)
print(word_freq)
# Out:
# Counter({Yo: 1, ,: 1, Matías: 1, Barreto: 1, ,: 1, estoy: 1, volando: 1, hacia: 1, Buenos: 1, Aires: 1, .: 1})

# %% [markdown]
# ## Caso 2

# %%
doc = nlp(u'En abril de 2025 estaremos realizando una introducción a spaCy para trabajar conceptos basicos de PNL')
for token in doc:
  print(token.text, token.lemma_)
# Out:
# En en
# abril abril
# de de
# 2025 2025
# estaremos estarer
# realizando realizar
# una uno
# introducción introducción
# a a
# spaCy spaCy
# para para
# trabajar trabajar
# conceptos concepto
# basicos basico
# de de
# PNL PNL

# %%
from spacy.lang.es.examples import sentences #agregamos la libreria sentences

doc = nlp(sentences[10])
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# ¿Dónde se encuentra la capital de Argentina?
# ¿ PUNCT punct
# Dónde PRON obl
# se PRON expl:pv
# encuentra VERB ROOT
# la DET det
# capital NOUN nsubj
# de ADP case
# Argentina PROPN nmod
# ? PUNCT punct

# %%
# from spacy.lang.es.examples import sentences

doc = nlp(sentences[11]) #el limite es 12
print(doc.text)
for token in doc:
    print(token.text, spacy.explain(token.pos_), token.dep_)
# Out:
# ¿Cuándo nació José de San Martín?
# ¿ punctuation punct
# Cuándo pronoun obj
# nació verb ROOT
# José proper noun nsubj
# de adposition case
# San proper noun flat
# Martín proper noun flat
# ? punctuation punct

# %%
from collections import Counter

# %%
word_freq = Counter(doc)
print(word_freq)
# Out:
# Counter({Veo: 1, al: 1, hombre: 1, con: 1, el: 1, telescopio: 1, .: 1})

# %%
from spacy import displacy
displacy.render(doc, style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="c8e45161b58d4208b8a64953b56bdf52-0" class="displacy" width="770" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Veo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">al</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">hombre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">con</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">telescopio.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c8e45161b58d4208b8a64953b56bdf52-0-0" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c8e45161b58d4208b8a64953b56bdf52-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c8e45161b58d4208b8a64953b56bdf52-0-1" stroke-width="2px" d="M70,182.0 C70,62.0 285.0,62.0 285.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c8e45161b58d4208b8a64953b56bdf52-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M285.0,184.0 L293.0,172.0 277.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c8e45161b58d4208b8a64953b56bdf52-0-2" stroke-width="2px" d="M430,182.0 C430,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c8e45161b58d4208b8a64953b56bdf52-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c8e45161b58d4208b8a64953b56bdf52-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c8e45161b58d4208b8a64953b56bdf52-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c8e45161b58d4208b8a64953b56bdf52-0-4" stroke-width="2px" d="M70,182.0 C70,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c8e45161b58d4208b8a64953b56bdf52-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,184.0 L658.0,172.0 642.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## Caso 3

# %%
from spacy import displacy #YA LA CARGAMOS ARRIBA

# %%
text = "Queremos viajar desde Buenos Aires a Mar del Plata y unos dias depues a La Plata"
doc = nlp(text)
displacy.render(doc,style='ent',jupyter=True,options={'distance':200})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Queremos viajar desde
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buenos Aires
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mar del Plata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y unos dias depues a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La Plata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>

# %%
text = "Su nombre es Benjamin; nació en Argentina."
doc = nlp(text)
displacy.render(doc,style='ent',jupyter=True,options={'distance':200})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Su nombre es
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benjamin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ; nació en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Argentina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="f4d7a3ad51f54811b6b53bc2dd0506fa-0" class="displacy" width="890" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Su</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">nombre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">es</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Benjamin;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">nació</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Argentina.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-0" stroke-width="2px" d="M70,122.0 C70,62.0 165.0,62.0 165.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-1" stroke-width="2px" d="M190,122.0 C190,2.0 410.0,2.0 410.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-2" stroke-width="2px" d="M310,122.0 C310,62.0 405.0,62.0 405.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,124.0 L302,112.0 318,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-3" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,124.0 L422,112.0 438,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-4" stroke-width="2px" d="M670,122.0 C670,62.0 765.0,62.0 765.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,124.0 L662,112.0 678,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-5" stroke-width="2px" d="M550,122.0 C550,2.0 770.0,2.0 770.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f4d7a3ad51f54811b6b53bc2dd0506fa-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,124.0 L778.0,112.0 762.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## Caso 4

# %%
for token in nlp("Mis padres y amigos viven en Buenos Aires."):
    print(token.text)
# Out:
# Mis
# padres
# y
# amigos
# viven
# en
# Buenos
# Aires
# .

# %%
for chunk in nlp("Mis padres y amigos viven en Buenos Aires.").noun_chunks:
      print(chunk.text)
# Out:
# Mis padres
# amigos
# Buenos Aires

# %% [markdown]
# ## Caso 4

# %%
from spacy.symbols import ORTH, NORM

# %%
doc = nlp(u"Estoy volando hacia Baires")
print([w.text for w in doc])
# Out:
# ['Estoy', 'volando', 'hacia', 'Baires']

# %%
from spacy.language import Language
from spacy.tokens import Token

# %%
# Componente personalizado para asignar lemas específicos
@Language.component("custom_lemmatizer")
def custom_lemmatizer(doc):
    for token in doc:
        if token.text == "Baires":
            token.lemma_ = "Buenos Aires"
    return doc

# Remove the existing custom component if it exists
if "custom_lemmatizer" in nlp.pipe_names:
    nlp.remove_pipe("custom_lemmatizer")

# Añadir el componente al pipeline
nlp.add_pipe("custom_lemmatizer", after='lemmatizer')

# Ejemplo de texto en español
doc = nlp(u'Estoy volando a Baires')
print([w.text for w in doc])
print([w.lemma_ for w in doc])
# Out:
# ['Estoy', 'volando', 'a', 'Baires']
# ['estar', 'volar', 'a', 'Buenos Aires']

# %% [markdown]
# Rehacemos el ejercicio usando el modelo *es_core_news_lg*

# %%
# !python -m spacy download es_core_news_lg -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.0/568.0 MB 1.4 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("es_core_news_lg") #para textos largos
import es_core_news_lg
nlp = es_core_news_lg.load()

# %% [markdown]
# Caso 1

# %%
doc = nlp(u'Yo, Matías Barreto, estoy volando hacia Buenos Aires.') #reemplazar con un web scrapping
print([w.text for w in doc])
# Out:
# ['Yo', ',', 'Matías', 'Barreto', ',', 'estoy', 'volando', 'hacia', 'Buenos', 'Aires', '.']

# %%
# Length of sentence
print("La cantidad de tokens es: ", len(doc))
# Out:
# La cantidad de tokens es:  11

# %%
# Print individual words (i.e., tokens)
print("Los tokens son: \n" + "_" * 20 + "\n")
for words in doc:
    print(words)
# Out:
# Los tokens son:
# ____________________
#
# Yo
# ,
# Matías
# Barreto
# ,
# estoy
# volando
# hacia
# Buenos
# Aires
# .

# %%
for token in doc:
  print(token.text, token.lemma_)
# Out:
# Yo yo
# , ,
# Matías Matías
# Barreto Barreto
# , ,
# estoy estar
# volando volar
# hacia hacia
# Buenos Buenos
# Aires Aires
# . .

# %%
# Iterar sobre los tokens en el documento y mostrar el texto y su etiqueta POS
for token in doc:
    print(token.text, token.pos_, spacy.explain(token.pos_))
# Out:
# Yo PRON pronoun
# , PUNCT punctuation
# Matías PROPN proper noun
# Barreto PROPN proper noun
# , PUNCT punctuation
# estoy AUX auxiliary
# volando VERB verb
# hacia ADP adposition
# Buenos PROPN proper noun
# Aires PROPN proper noun
# . PUNCT punctuation

# %%
from collections import Counter

# %%
word_freq = Counter(doc)
print(word_freq)
# Out:
# Counter({Yo: 1, ,: 1, Matías: 1, Barreto: 1, ,: 1, estoy: 1, volando: 1, hacia: 1, Buenos: 1, Aires: 1, .: 1})

# %% [markdown]
# Caso 2

# %%
text = "Queremos viajar desde Buenos Aires a Mar del Plata y unos dias depues a La Plata"
doc = nlp(text)
displacy.render(doc,style='ent',jupyter=True,options={'distance':200})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Queremos viajar desde
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buenos Aires
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mar del Plata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y unos dias depues a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La Plata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>

# %%
text = "Su nombre es Benjamin; nació en Argentina."
doc = nlp(text)
displacy.render(doc,style='ent',jupyter=True,options={'distance':200})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Su nombre es
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benjamin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ; nació en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Argentina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>

# %% [markdown]
# En este caso, Benjamin lo toma como persona y no como localidad, por ello en el siguiente grafico, el orden es Benjamin nació, porque habla de la persona y no al reves, ya que no reconoce la palabra Benjamin como localidad de nacimiento de la persona.

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="09b391b9d20f407e9e67d111083127ac-0" class="displacy" width="890" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Su</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">nombre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">es</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Benjamin;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">nació</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Argentina.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-09b391b9d20f407e9e67d111083127ac-0-0" stroke-width="2px" d="M70,122.0 C70,62.0 165.0,62.0 165.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-09b391b9d20f407e9e67d111083127ac-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-09b391b9d20f407e9e67d111083127ac-0-1" stroke-width="2px" d="M190,122.0 C190,2.0 410.0,2.0 410.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-09b391b9d20f407e9e67d111083127ac-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-09b391b9d20f407e9e67d111083127ac-0-2" stroke-width="2px" d="M310,122.0 C310,62.0 405.0,62.0 405.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-09b391b9d20f407e9e67d111083127ac-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,124.0 L302,112.0 318,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-09b391b9d20f407e9e67d111083127ac-0-3" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-09b391b9d20f407e9e67d111083127ac-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,124.0 L533.0,112.0 517.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-09b391b9d20f407e9e67d111083127ac-0-4" stroke-width="2px" d="M670,122.0 C670,62.0 765.0,62.0 765.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-09b391b9d20f407e9e67d111083127ac-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,124.0 L662,112.0 678,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-09b391b9d20f407e9e67d111083127ac-0-5" stroke-width="2px" d="M550,122.0 C550,2.0 770.0,2.0 770.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-09b391b9d20f407e9e67d111083127ac-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,124.0 L778.0,112.0 762.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
from spacy.lang.es.examples import sentences #agregamos la libreria sentences

doc = nlp(sentences[10])
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# ¿Dónde se encuentra la capital de Argentina?
# ¿ PUNCT punct
# Dónde PRON obl
# se PRON expl:pv
# encuentra VERB ROOT
# la DET det
# capital NOUN nsubj
# de ADP case
# Argentina PROPN nmod
# ? PUNCT punct

# %%
# from spacy.lang.es.examples import sentences

doc = nlp(sentences[11]) #el limite es 12
print(doc.text)
for token in doc:
    print(token.text, spacy.explain(token.pos_), token.dep_)
# Out:
# ¿Cuándo nació José de San Martín?
# ¿ punctuation punct
# Cuándo pronoun obj
# nació verb ROOT
# José proper noun nsubj
# de adposition case
# San proper noun flat
# Martín proper noun flat
# ? punctuation punct
